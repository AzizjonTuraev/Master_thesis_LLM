# %% [markdown]
# ## Random Forest Classifier

# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, accuracy_score, roc_auc_score, precision_score, recall_score 
from sklearn.preprocessing import LabelEncoder

import os

# %%
file_name = "adult_original_test.csv"
org_test_df = pd.read_csv(f"../data_split/original_test_dataset/{file_name}")

org_test_df.head()
# Out:
#    age workclass  fnlwgt  educational-num marital-status    occupation  \
# 0   32    Others   33117               11        Married        Others
# 1   51    Others  233149               12        Married  White Collar
# 2   84    Others  188328                9         Single  White Collar
# 3   45    Others  158685                9         Single  White Collar
# 4   44    Others  112847                4        Married   Blue Collar
#
#                  race  gender  capital-gain  capital-loss  hours-per-week  \
# 0               White    Male             0             0              40
# 1               White    Male             0             0              45
# 2               White  Female             0             0              16
# 3               White  Female             0             0              40
# 4  Asian-Pac-Islander    Male             0             0              40
#
#   native-country income
# 0  United-States  <=50K
# 1  United-States   >50K
# 2  United-States  <=50K
# 3  United-States  <=50K
# 4    Philippines  <=50K

# %%
file_name = "adult_original_train.csv"
org_train_df = pd.read_csv(f"../data_split/original_train_dataset/{file_name}")

org_train_df.head()
# Out:
#    age workclass  fnlwgt  educational-num marital-status    occupation   race  \
# 0   22    Others   51362               13         Single  White Collar  White
# 1   41    Others  203217                4         Single   Blue Collar  White
# 2   25    Others   51498                8         Single        Others  White
# 3   28    Others  179512                9         Single  White Collar  White
# 4   42    Others  177989                9        Married   Blue Collar  White
#
#    gender  capital-gain  capital-loss  hours-per-week native-country income
# 0  Female             0             0              16  United-States  <=50K
# 1    Male             0             0              40         Mexico  <=50K
# 2    Male             0             0              40  United-States  <=50K
# 3  Female             0             0              50  United-States  <=50K
# 4    Male             0             0              40  United-States  <=50K

# %%
print("Len of original test dataset:", len(org_test_df))
print("Len of original train dataset:", len(org_train_df))
# Out:
# Len of original test dataset: 14904
# Len of original train dataset: 30260

# %%
le_workclass = LabelEncoder()
le_marital_status = LabelEncoder()
le_occupation = LabelEncoder()
le_race = LabelEncoder()
le_gender = LabelEncoder()
le_native_country = LabelEncoder()
le_income = LabelEncoder()

column_name = "workclass"
org_train_df[column_name] = le_workclass.fit_transform(org_train_df[column_name])
org_test_df[column_name] = le_workclass.transform(org_test_df[column_name])

column_name = "marital-status"
org_train_df[column_name] = le_marital_status.fit_transform(org_train_df[column_name])
org_test_df[column_name] = le_marital_status.transform(org_test_df[column_name])

column_name = "occupation"
org_train_df[column_name] = le_occupation.fit_transform(org_train_df[column_name])
org_test_df[column_name] = le_occupation.transform(org_test_df[column_name])

column_name = "race"
org_train_df[column_name] = le_race.fit_transform(org_train_df[column_name])
org_test_df[column_name] = le_race.transform(org_test_df[column_name])

column_name = "gender"
org_train_df[column_name] = le_gender.fit_transform(org_train_df[column_name])
org_test_df[column_name] = le_gender.transform(org_test_df[column_name])

column_name = "native-country"
org_train_df[column_name] = le_native_country.fit_transform(org_train_df[column_name])
org_test_df[column_name] = le_native_country.transform(org_test_df[column_name])

column_name = "income"
org_train_df[column_name] = le_income.fit_transform(org_train_df[column_name])
org_test_df[column_name] = le_income.transform(org_test_df[column_name])

# %%
X_train = org_train_df.drop("income", axis=1)
Y_train = org_train_df["income"]

X_test_org = org_test_df.drop("income", axis=1)
Y_test_org = org_test_df["income"]

# %%
ml = RandomForestClassifier(random_state=32)
ml.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(random_state=32)

# %%
y_predict_test_org= ml.predict(X_test_org)

# %%
current_path = os.getcwd()
current_path
# Out:
# 'c:\\__Local Disk D\\master thesis submit version\\execution\\results_analysis_code'

# %%
dataset_folder = "adult"
dataset_folder = f"../generated_datasets/{dataset_folder}"
models_name = os.listdir(dataset_folder)
models_name
# Out:
# ['great_gpt2_12_layer_adult',
#  'great_gpt2_6_layer_adult',
#  'realtab_gpt2_12_layer_adult',
#  'realtab_gpt2_6_layer_adult',
#  'realtab_gpt_bigcode_12_layer_adult',
#  'realtab_gpt_bigcode_6_layer_adult',
#  'realtab_gpt_neo_2_layer_adult',
#  'realtab_gpt_neo_4_layer_adult',
#  'realtab_gpt_neo_6_layer_adult',
#  'realtab_gpt_neo_8_layer_adult',
#  'realtab_llama_1_layer_adult',
#  'realtab_llama_2_layer_adult']

# %%
outputs = []

for model in models_name:

    model_output = {"model_name" : model}
    # print(model)

    for i in range(1, 6):
        # print(i)
        synt_test_df = pd.read_csv(f"../generated_datasets/{dataset_folder}/{model}/samples/test/sample{i}.csv", sep=",")[:14904]

        if "Unnamed: 0" in synt_test_df.columns:
            synt_test_df = synt_test_df.drop('Unnamed: 0', axis=1)

        column_name = "workclass"
        synt_test_df[column_name] = le_workclass.transform(synt_test_df[column_name])
        column_name = "marital-status"
        synt_test_df[column_name] = le_marital_status.transform(synt_test_df[column_name])
        column_name = "occupation"
        synt_test_df[column_name] = le_occupation.transform(synt_test_df[column_name])
        column_name = "race"
        synt_test_df[column_name] = le_race.transform(synt_test_df[column_name])
        column_name = "gender"
        synt_test_df[column_name] = le_gender.transform(synt_test_df[column_name])
        column_name = "native-country"
        synt_test_df[column_name] = le_native_country.transform(synt_test_df[column_name])
        column_name = "income"
        synt_test_df[column_name] = le_income.transform(synt_test_df[column_name])

        X_test_synt = synt_test_df.drop("income", axis=1)
        Y_test_synt = synt_test_df["income"]

        y_predict_syn_test = ml.predict(X_test_synt)
        f1_score_micro = f1_score(Y_test_synt, y_predict_syn_test, average='micro')
        f1_score_macro = f1_score(Y_test_synt, y_predict_syn_test, average='macro')
        f1_score_weighted = f1_score(Y_test_synt, y_predict_syn_test, average='weighted')
        accuracy_ = accuracy_score(Y_test_synt, y_predict_syn_test)
        precision_ = precision_score(Y_test_synt, y_predict_syn_test)
        recall_ = recall_score(Y_test_synt, y_predict_syn_test)

        model_output[i] = {
            "f1_score_micro": f1_score_micro,
            "f1_score_macro": f1_score_macro,
            "f1_score_weighted": f1_score_weighted,
            "accuracy": accuracy_,
            "precision": precision_,
            "recall": recall_,
        }

    outputs.append(model_output)

# %%
stats = {}

for model in outputs:
    f1_score_micro = []
    f1_score_macro = []
    f1_score_weighted = []
    accuracy_ = []
    precision_ = []
    recall_ = []

    for i in range(1, 6):
        f1_score_micro.append(model[i]["f1_score_micro"])
        f1_score_macro.append(model[i]["f1_score_macro"])
        f1_score_weighted.append(model[i]["f1_score_weighted"])
        accuracy_.append(model[i]["accuracy"])
        precision_.append(model[i]["precision"])
        recall_.append(model[i]["recall"])
    
    f1_score_micro_mean = np.mean(f1_score_micro)
    f1_score_micro_std = np.std(f1_score_micro, ddof=1)
    f1_score_macro_mean = np.mean(f1_score_macro)
    f1_score_macro_std = np.std(f1_score_macro, ddof=1)
    f1_score_weighted_mean = np.mean(f1_score_weighted)
    f1_score_weighted_std = np.std(f1_score_weighted, ddof=1)
    accuracy_mean = np.mean(accuracy_)
    accuracy_std = np.std(accuracy_, ddof=1)
    precision_mean = np.mean(precision_)
    precision_std = np.std(precision_, ddof=1)
    recall_mean = np.mean(recall_)
    recall_std = np.std(recall_, ddof=1)

    stats[model["model_name"]] = {
        "f1_score_micro": f1_score_micro_mean, 
        "f1_score_micro_std": f1_score_micro_std,
        "f1_score_macro": f1_score_macro_mean,
        "f1_score_macro_std": f1_score_macro_std,
        "f1_score_weighted": f1_score_weighted_mean,
        "f1_score_weighted_std": f1_score_weighted_std,
        "accuracy": accuracy_mean,
        "accuracy_std": accuracy_std,
        "precision": precision_mean,
        "precision_std": precision_std,
        "recall": recall_mean,
        "recall_std": recall_std        
    }

# %%
f1_score_micro = f1_score(Y_test_org, y_predict_test_org, average='micro')
f1_score_macro = f1_score(Y_test_org, y_predict_test_org, average='macro')
f1_score_weighted = f1_score(Y_test_org, y_predict_test_org, average='weighted')
accuracy_ = accuracy_score(Y_test_org, y_predict_test_org)
precision_ = precision_score(Y_test_org, y_predict_test_org)
recall_ = recall_score(Y_test_org, y_predict_test_org)

original = {
                "f1_score_micro" : f1_score_micro,
                "f1_score_micro_std" : 0,
                "f1_score_macro" : f1_score_macro,
                "f1_score_macro_std" : 0,
                "f1_score_weighted" : f1_score_weighted,
                "f1_score_weighted_std" : 0,
                "accuracy" : accuracy_,
                "accuracy_std" : 0,
                "precision" : precision_,
                "precision_std" : 0,
                "recall" : recall_,
                "recall_std" : 0
            }

stats["original"] = original

# %%
pd.DataFrame(stats).loc[["f1_score_macro", "f1_score_macro_std"]].T
# Out:
#                                     f1_score_macro  f1_score_macro_std
# great_gpt2_12_layer_adult                 0.786043            0.004309
# great_gpt2_6_layer_adult                  0.777030            0.003556
# realtab_gpt2_12_layer_adult               0.795454            0.001883
# realtab_gpt2_6_layer_adult                0.801522            0.002989
# realtab_gpt_bigcode_12_layer_adult        0.792441            0.004352
# realtab_gpt_bigcode_6_layer_adult         0.806099            0.005174
# realtab_gpt_neo_2_layer_adult             0.793311            0.017591
# realtab_gpt_neo_4_layer_adult             0.784295            0.001649
# realtab_gpt_neo_6_layer_adult             0.767416            0.003105
# realtab_gpt_neo_8_layer_adult             0.773803            0.004173
# realtab_llama_1_layer_adult               0.778701            0.002304
# realtab_llama_2_layer_adult               0.812146            0.008456
# original                                  0.779398            0.000000

# %%
pd.DataFrame(stats).loc[["accuracy", "accuracy_std"]].T
# Out:
#                                     accuracy  accuracy_std
# great_gpt2_12_layer_adult           0.847692      0.003734
# great_gpt2_6_layer_adult            0.841908      0.001113
# realtab_gpt2_12_layer_adult         0.838218      0.001094
# realtab_gpt2_6_layer_adult          0.860990      0.001876
# realtab_gpt_bigcode_12_layer_adult  0.852402      0.002712
# realtab_gpt_bigcode_6_layer_adult   0.857568      0.003572
# realtab_gpt_neo_2_layer_adult       0.850450      0.012629
# realtab_gpt_neo_4_layer_adult       0.833897      0.001962
# realtab_gpt_neo_6_layer_adult       0.846095      0.001890
# realtab_gpt_neo_8_layer_adult       0.846122      0.001943
# realtab_llama_1_layer_adult         0.845813      0.002197
# realtab_llama_2_layer_adult         0.867633      0.005160
# original                            0.845008      0.000000

# %% [markdown]
# ## Logistic Regression

# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, accuracy_score, roc_auc_score, precision_score, recall_score 
from sklearn.preprocessing import LabelEncoder

import os

from general_mle import mle_adult

# %%
file_name = "adult_original_test.csv"
org_test_df = pd.read_csv(f"../data_split/original_test_dataset/{file_name}")

file_name = "adult_original_train.csv"
org_train_df = pd.read_csv(f"../data_split/original_train_dataset/{file_name}")

dataset_folder = "adult"
dataset_folder = f"../generated_datasets/{dataset_folder}"

# %%
file_name = "adult_original_train.csv"
org_train_df = pd.read_csv(f"../data_split/original_train_dataset/{file_name}")

org_train_df.head()
# Out:
#    age workclass  fnlwgt  educational-num marital-status    occupation   race  \
# 0   22    Others   51362               13         Single  White Collar  White
# 1   41    Others  203217                4         Single   Blue Collar  White
# 2   25    Others   51498                8         Single        Others  White
# 3   28    Others  179512                9         Single  White Collar  White
# 4   42    Others  177989                9        Married   Blue Collar  White
#
#    gender  capital-gain  capital-loss  hours-per-week native-country income
# 0  Female             0             0              16  United-States  <=50K
# 1    Male             0             0              40         Mexico  <=50K
# 2    Male             0             0              40  United-States  <=50K
# 3  Female             0             0              50  United-States  <=50K
# 4    Male             0             0              40  United-States  <=50K

# %%
temp = mle_adult(org_test_df=org_test_df, org_train_df=org_train_df, ml_model=LogisticRegression(random_state=32),
                            path_to_synthetic_data=dataset_folder)
# Out:
# c:\Users\Azizjon\anaconda3\envs\test\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
pd.DataFrame(stats).loc[["f1_score_macro", "f1_score_macro_std"]].T
# Out:
#                                     f1_score_macro  f1_score_macro_std
# great_gpt2_12_layer_adult                 0.786043            0.004309
# great_gpt2_6_layer_adult                  0.777030            0.003556
# realtab_gpt2_12_layer_adult               0.795454            0.001883
# realtab_gpt2_6_layer_adult                0.801522            0.002989
# realtab_gpt_bigcode_12_layer_adult        0.792441            0.004352
# realtab_gpt_bigcode_6_layer_adult         0.806099            0.005174
# realtab_gpt_neo_2_layer_adult             0.793311            0.017591
# realtab_gpt_neo_4_layer_adult             0.784295            0.001649
# realtab_gpt_neo_6_layer_adult             0.767416            0.003105
# realtab_gpt_neo_8_layer_adult             0.773803            0.004173
# realtab_llama_1_layer_adult               0.778701            0.002304
# realtab_llama_2_layer_adult               0.812146            0.008456
# original                                  0.779398            0.000000

# %%
pd.DataFrame(stats).loc[["accuracy", "accuracy_std"]].T
# Out:
#                                     accuracy  accuracy_std
# great_gpt2_12_layer_adult           0.847692      0.003734
# great_gpt2_6_layer_adult            0.841908      0.001113
# realtab_gpt2_12_layer_adult         0.838218      0.001094
# realtab_gpt2_6_layer_adult          0.860990      0.001876
# realtab_gpt_bigcode_12_layer_adult  0.852402      0.002712
# realtab_gpt_bigcode_6_layer_adult   0.857568      0.003572
# realtab_gpt_neo_2_layer_adult       0.850450      0.012629
# realtab_gpt_neo_4_layer_adult       0.833897      0.001962
# realtab_gpt_neo_6_layer_adult       0.846095      0.001890
# realtab_gpt_neo_8_layer_adult       0.846122      0.001943
# realtab_llama_1_layer_adult         0.845813      0.002197
# realtab_llama_2_layer_adult         0.867633      0.005160
# original                            0.845008      0.000000

# %% [markdown]
# ## Catboost

# %%
import pandas as pd
import numpy as np

from catboost import CatBoostClassifier
from sklearn.metrics import f1_score, accuracy_score, roc_auc_score, precision_score, recall_score 
from sklearn.preprocessing import LabelEncoder

import os

from general_mle import mle_adult

# %%
file_name = "adult_original_test.csv"
org_test_df = pd.read_csv(f"../data_split/original_test_dataset/{file_name}")

file_name = "adult_original_train.csv"
org_train_df = pd.read_csv(f"../data_split/original_train_dataset/{file_name}")

dataset_folder = "adult"
dataset_folder = f"../generated_datasets/{dataset_folder}"

# %%
temp = mle_adult(org_test_df=org_test_df, org_train_df=org_train_df, ml_model=CatBoostClassifier(random_state=32),
                            path_to_synthetic_data=dataset_folder)
# Out:
# Learning rate set to 0.044184
# 0:	learn: 0.6503175	total: 142ms	remaining: 2m 21s
# 1:	learn: 0.6096526	total: 152ms	remaining: 1m 15s
# 2:	learn: 0.5782235	total: 160ms	remaining: 53.3s
# 3:	learn: 0.5474095	total: 167ms	remaining: 41.7s
# 4:	learn: 0.5199013	total: 175ms	remaining: 34.7s
# 5:	learn: 0.4994793	total: 182ms	remaining: 30.1s
# 6:	learn: 0.4787114	total: 190ms	remaining: 27s
# 7:	learn: 0.4630303	total: 198ms	remaining: 24.6s
# 8:	learn: 0.4470104	total: 204ms	remaining: 22.5s
# 9:	learn: 0.4331414	total: 212ms	remaining: 21s
# 10:	learn: 0.4216798	total: 219ms	remaining: 19.6s
# 11:	learn: 0.4108738	total: 229ms	remaining: 18.8s
# 12:	learn: 0.4022098	total: 236ms	remaining: 18s
# 13:	learn: 0.3945132	total: 244ms	remaining: 17.2s
# 14:	learn: 0.3880601	total: 251ms	remaining: 16.5s
# 15:	learn: 0.3818304	total: 258ms	remaining: 15.9s
# 16:	learn: 0.3771999	total: 264ms	remaining: 15.3s
# 17:	learn: 0.3712705	total: 271ms	remaining: 14.8s
# 18:	learn: 0.3670281	total: 278ms	remaining: 14.3s
# 19:	learn: 0.3627767	total: 285ms	remaining: 13.9s
# 20:	learn: 0.3590343	total: 293ms	remaining: 13.6s
# 21:	learn: 0.3555371	total: 299ms	remaining: 13.3s
# 22:	learn: 0.3526335	total: 306ms	remaining: 13s
# 23:	learn: 0.3501092	total: 313ms	remaining: 12.7s
# 24:	learn: 0.3473735	total: 321ms	remaining: 12.5s
# 25:	learn: 0.3455782	total: 328ms	remaining: 12.3s
# 26:	learn: 0.3432290	total: 335ms	remaining: 12.1s
# 27:	learn: 0.3412707	total: 343ms	remaining: 11.9s
# 28:	learn: 0.3390996	total: 350ms	remaining: 11.7s
# 29:	learn: 0.3376673	total: 359ms	remaining: 11.6s
# 30:	learn: 0.3364390	total: 366ms	remaining: 11.4s
# 218:	learn: 0.2872615	total: 1.68s	remaining: 5.98s
# 219:	learn: 0.2868818	total: 1.68s	remaining: 5.96s
# 220:	learn: 0.2868203	total: 1.69s	remaining: 5.96s
# 221:	learn: 0.2867392	total: 1.7s	remaining: 5.94s
# 222:	learn: 0.2866544	total: 1.7s	remaining: 5.93s
# 223:	learn: 0.2865454	total: 1.71s	remaining: 5.92s
# 224:	learn: 0.2864986	total: 1.72s	remaining: 5.91s
# 225:	learn: 0.2861581	total: 1.72s	remaining: 5.9s
# 226:	learn: 0.2860567	total: 1.73s	remaining: 5.89s
# 227:	learn: 0.2859564	total: 1.73s	remaining: 5.87s
# 228:	learn: 0.2859219	total: 1.74s	remaining: 5.86s
# 229:	learn: 0.2857816	total: 1.75s	remaining: 5.85s
# 230:	learn: 0.2856820	total: 1.75s	remaining: 5.84s
# 231:	learn: 0.2855167	total: 1.76s	remaining: 5.83s
# 232:	learn: 0.2853709	total: 1.76s	remaining: 5.81s
# 233:	learn: 0.2852751	total: 1.77s	remaining: 5.8s
# 234:	learn: 0.2852475	total: 1.78s	remaining: 5.79s
# 235:	learn: 0.2851908	total: 1.78s	remaining: 5.77s
# 236:	learn: 0.2851341	total: 1.79s	remaining: 5.76s
# 237:	learn: 0.2850846	total: 1.79s	remaining: 5.75s
# 238:	learn: 0.2850518	total: 1.8s	remaining: 5.74s
# 239:	learn: 0.2850020	total: 1.81s	remaining: 5.72s
# 240:	learn: 0.2849561	total: 1.81s	remaining: 5.71s
# 241:	learn: 0.2849010	total: 1.82s	remaining: 5.7s
# 242:	learn: 0.2848027	total: 1.83s	remaining: 5.69s
# 243:	learn: 0.2847160	total: 1.83s	remaining: 5.68s
# 244:	learn: 0.2846768	total: 1.84s	remaining: 5.67s
# 245:	learn: 0.2844690	total: 1.85s	remaining: 5.66s
# 246:	learn: 0.2844173	total: 1.85s	remaining: 5.65s
# 247:	learn: 0.2843707	total: 1.86s	remaining: 5.64s
# 248:	learn: 0.2843230	total: 1.87s	remaining: 5.63s
# 249:	learn: 0.2842836	total: 1.87s	remaining: 5.62s
# 250:	learn: 0.2842030	total: 1.88s	remaining: 5.61s
# 251:	learn: 0.2841502	total: 1.89s	remaining: 5.6s
# 252:	learn: 0.2840921	total: 1.89s	remaining: 5.58s
# 253:	learn: 0.2838889	total: 1.9s	remaining: 5.58s
# 254:	learn: 0.2838309	total: 1.9s	remaining: 5.56s
# 255:	learn: 0.2837693	total: 1.91s	remaining: 5.55s
# 256:	learn: 0.2836866	total: 1.92s	remaining: 5.54s
# 257:	learn: 0.2835164	total: 1.92s	remaining: 5.53s
# 258:	learn: 0.2834397	total: 1.93s	remaining: 5.52s
# 259:	learn: 0.2834009	total: 1.94s	remaining: 5.51s
# 260:	learn: 0.2833202	total: 1.94s	remaining: 5.5s
# 261:	learn: 0.2832778	total: 1.95s	remaining: 5.49s
# 262:	learn: 0.2832272	total: 1.95s	remaining: 5.48s
# 263:	learn: 0.2831737	total: 1.96s	remaining: 5.46s
# 264:	learn: 0.2830457	total: 1.97s	remaining: 5.45s
# 265:	learn: 0.2829106	total: 1.97s	remaining: 5.44s
# 266:	learn: 0.2826688	total: 1.98s	remaining: 5.43s
# 267:	learn: 0.2826237	total: 1.98s	remaining: 5.42s
# 268:	learn: 0.2825645	total: 1.99s	remaining: 5.41s
# 269:	learn: 0.2825233	total: 2s	remaining: 5.4s
# 270:	learn: 0.2824549	total: 2s	remaining: 5.38s
# 271:	learn: 0.2823829	total: 2.01s	remaining: 5.38s
# 272:	learn: 0.2823279	total: 2.02s	remaining: 5.37s
# 273:	learn: 0.2822790	total: 2.02s	remaining: 5.35s
# 274:	learn: 0.2822177	total: 2.03s	remaining: 5.35s
# 275:	learn: 0.2821601	total: 2.04s	remaining: 5.34s
# 276:	learn: 0.2820799	total: 2.04s	remaining: 5.33s
# 277:	learn: 0.2818740	total: 2.05s	remaining: 5.33s
# 278:	learn: 0.2818119	total: 2.06s	remaining: 5.32s
# 279:	learn: 0.2817361	total: 2.06s	remaining: 5.31s
# 280:	learn: 0.2816686	total: 2.07s	remaining: 5.3s
# 281:	learn: 0.2815740	total: 2.08s	remaining: 5.29s
# 282:	learn: 0.2814985	total: 2.08s	remaining: 5.28s
# 283:	learn: 0.2814266	total: 2.09s	remaining: 5.27s
# 284:	learn: 0.2813691	total: 2.1s	remaining: 5.26s
# 285:	learn: 0.2812757	total: 2.1s	remaining: 5.25s
# 286:	learn: 0.2812349	total: 2.11s	remaining: 5.24s
# 287:	learn: 0.2811860	total: 2.11s	remaining: 5.23s
# 288:	learn: 0.2811246	total: 2.12s	remaining: 5.22s
# 289:	learn: 0.2808830	total: 2.13s	remaining: 5.21s
# 290:	learn: 0.2806472	total: 2.13s	remaining: 5.2s
# 291:	learn: 0.2806166	total: 2.14s	remaining: 5.19s
# 292:	learn: 0.2805532	total: 2.15s	remaining: 5.18s
# 293:	learn: 0.2804785	total: 2.15s	remaining: 5.17s
# 294:	learn: 0.2803991	total: 2.16s	remaining: 5.16s
# 295:	learn: 0.2803284	total: 2.17s	remaining: 5.15s
# 296:	learn: 0.2802789	total: 2.17s	remaining: 5.14s
# 297:	learn: 0.2802291	total: 2.18s	remaining: 5.13s
# 298:	learn: 0.2801128	total: 2.18s	remaining: 5.12s
# 299:	learn: 0.2800613	total: 2.19s	remaining: 5.11s
# 300:	learn: 0.2799643	total: 2.2s	remaining: 5.1s
# 301:	learn: 0.2798884	total: 2.2s	remaining: 5.09s
# 302:	learn: 0.2796849	total: 2.21s	remaining: 5.08s
# 303:	learn: 0.2795884	total: 2.22s	remaining: 5.08s
# 304:	learn: 0.2795578	total: 2.22s	remaining: 5.06s
# 305:	learn: 0.2793056	total: 2.23s	remaining: 5.06s
# 306:	learn: 0.2792324	total: 2.24s	remaining: 5.05s
# 307:	learn: 0.2791403	total: 2.24s	remaining: 5.04s
# 308:	learn: 0.2791083	total: 2.25s	remaining: 5.03s
# 309:	learn: 0.2789272	total: 2.26s	remaining: 5.03s
# 723:	learn: 0.2589081	total: 5.2s	remaining: 1.98s
# 724:	learn: 0.2588605	total: 5.21s	remaining: 1.98s
# 725:	learn: 0.2588321	total: 5.21s	remaining: 1.97s
# 726:	learn: 0.2588070	total: 5.22s	remaining: 1.96s
# 727:	learn: 0.2587827	total: 5.23s	remaining: 1.95s
# 728:	learn: 0.2587722	total: 5.24s	remaining: 1.95s
# 729:	learn: 0.2587378	total: 5.24s	remaining: 1.94s
# 730:	learn: 0.2587155	total: 5.25s	remaining: 1.93s
# 731:	learn: 0.2586830	total: 5.26s	remaining: 1.92s
# 732:	learn: 0.2586510	total: 5.26s	remaining: 1.92s
# 733:	learn: 0.2586160	total: 5.27s	remaining: 1.91s
# 734:	learn: 0.2585914	total: 5.28s	remaining: 1.9s
# 735:	learn: 0.2585523	total: 5.28s	remaining: 1.9s
# 736:	learn: 0.2584764	total: 5.29s	remaining: 1.89s
# 737:	learn: 0.2584528	total: 5.3s	remaining: 1.88s
# 738:	learn: 0.2584029	total: 5.3s	remaining: 1.87s
# 739:	learn: 0.2583693	total: 5.31s	remaining: 1.87s
# 740:	learn: 0.2583002	total: 5.32s	remaining: 1.86s
# 741:	learn: 0.2582595	total: 5.33s	remaining: 1.85s
# 742:	learn: 0.2582430	total: 5.33s	remaining: 1.84s
# 743:	learn: 0.2582149	total: 5.34s	remaining: 1.84s
# 744:	learn: 0.2581759	total: 5.35s	remaining: 1.83s
# 745:	learn: 0.2581252	total: 5.36s	remaining: 1.82s
# 746:	learn: 0.2580835	total: 5.37s	remaining: 1.82s
# 747:	learn: 0.2580373	total: 5.38s	remaining: 1.81s
# 748:	learn: 0.2579596	total: 5.38s	remaining: 1.8s
# 749:	learn: 0.2579417	total: 5.39s	remaining: 1.8s
# 750:	learn: 0.2579035	total: 5.4s	remaining: 1.79s
# 751:	learn: 0.2578505	total: 5.41s	remaining: 1.78s
# 752:	learn: 0.2577779	total: 5.41s	remaining: 1.77s
# 753:	learn: 0.2577162	total: 5.42s	remaining: 1.77s
# 754:	learn: 0.2577036	total: 5.43s	remaining: 1.76s
# 755:	learn: 0.2576519	total: 5.44s	remaining: 1.75s
# 756:	learn: 0.2576250	total: 5.45s	remaining: 1.75s
# 757:	learn: 0.2575978	total: 5.46s	remaining: 1.74s
# 758:	learn: 0.2575814	total: 5.46s	remaining: 1.73s
# 759:	learn: 0.2575295	total: 5.47s	remaining: 1.73s
# 760:	learn: 0.2574805	total: 5.48s	remaining: 1.72s
# 761:	learn: 0.2574660	total: 5.49s	remaining: 1.71s
# 762:	learn: 0.2574482	total: 5.49s	remaining: 1.71s
# 763:	learn: 0.2574196	total: 5.5s	remaining: 1.7s
# 764:	learn: 0.2573888	total: 5.51s	remaining: 1.69s
# 765:	learn: 0.2573413	total: 5.52s	remaining: 1.69s
# 766:	learn: 0.2573126	total: 5.52s	remaining: 1.68s
# 767:	learn: 0.2572622	total: 5.53s	remaining: 1.67s
# 768:	learn: 0.2572293	total: 5.54s	remaining: 1.66s
# 769:	learn: 0.2571647	total: 5.55s	remaining: 1.66s
# 770:	learn: 0.2571236	total: 5.55s	remaining: 1.65s
# 771:	learn: 0.2571126	total: 5.56s	remaining: 1.64s
# 772:	learn: 0.2570911	total: 5.57s	remaining: 1.64s
# 773:	learn: 0.2570532	total: 5.58s	remaining: 1.63s
# 774:	learn: 0.2570061	total: 5.59s	remaining: 1.62s
# 775:	learn: 0.2569518	total: 5.6s	remaining: 1.61s
# 776:	learn: 0.2569243	total: 5.6s	remaining: 1.61s
# 777:	learn: 0.2568819	total: 5.61s	remaining: 1.6s
# 778:	learn: 0.2568704	total: 5.62s	remaining: 1.59s
# 779:	learn: 0.2568284	total: 5.62s	remaining: 1.59s
# 780:	learn: 0.2568107	total: 5.63s	remaining: 1.58s
# 781:	learn: 0.2567646	total: 5.64s	remaining: 1.57s
# 782:	learn: 0.2567277	total: 5.65s	remaining: 1.56s
# 783:	learn: 0.2566588	total: 5.65s	remaining: 1.56s
# 784:	learn: 0.2566049	total: 5.66s	remaining: 1.55s
# 785:	learn: 0.2565545	total: 5.67s	remaining: 1.54s
# 786:	learn: 0.2565422	total: 5.68s	remaining: 1.54s
# 787:	learn: 0.2565149	total: 5.68s	remaining: 1.53s
# 788:	learn: 0.2564620	total: 5.69s	remaining: 1.52s
# 789:	learn: 0.2564135	total: 5.7s	remaining: 1.51s
# 790:	learn: 0.2563603	total: 5.71s	remaining: 1.51s
# 791:	learn: 0.2563237	total: 5.71s	remaining: 1.5s
# 792:	learn: 0.2562827	total: 5.72s	remaining: 1.49s
# 793:	learn: 0.2562276	total: 5.73s	remaining: 1.49s
# 794:	learn: 0.2561693	total: 5.74s	remaining: 1.48s
# 795:	learn: 0.2561601	total: 5.75s	remaining: 1.47s
# 796:	learn: 0.2561544	total: 5.75s	remaining: 1.47s
# 797:	learn: 0.2561320	total: 5.76s	remaining: 1.46s
# 798:	learn: 0.2560889	total: 5.77s	remaining: 1.45s
# 799:	learn: 0.2560542	total: 5.78s	remaining: 1.44s
# 800:	learn: 0.2560048	total: 5.78s	remaining: 1.44s
# 801:	learn: 0.2559634	total: 5.79s	remaining: 1.43s
# 802:	learn: 0.2559230	total: 5.8s	remaining: 1.42s
# 803:	learn: 0.2558948	total: 5.81s	remaining: 1.42s
# 804:	learn: 0.2558664	total: 5.82s	remaining: 1.41s
# 805:	learn: 0.2558347	total: 5.83s	remaining: 1.4s
# 806:	learn: 0.2558259	total: 5.83s	remaining: 1.4s
# 807:	learn: 0.2557895	total: 5.84s	remaining: 1.39s
# 808:	learn: 0.2557393	total: 5.85s	remaining: 1.38s
# 809:	learn: 0.2557039	total: 5.86s	remaining: 1.37s
# 810:	learn: 0.2556623	total: 5.87s	remaining: 1.37s
# 811:	learn: 0.2556585	total: 5.88s	remaining: 1.36s
# 812:	learn: 0.2556441	total: 5.89s	remaining: 1.35s
# 813:	learn: 0.2556342	total: 5.9s	remaining: 1.35s
# 814:	learn: 0.2555492	total: 5.9s	remaining: 1.34s
# 815:	learn: 0.2555125	total: 5.91s	remaining: 1.33s
# 816:	learn: 0.2554994	total: 5.92s	remaining: 1.33s
# 817:	learn: 0.2554514	total: 5.93s	remaining: 1.32s
# 818:	learn: 0.2554116	total: 5.94s	remaining: 1.31s
# 819:	learn: 0.2553942	total: 5.95s	remaining: 1.3s
# 820:	learn: 0.2553521	total: 5.95s	remaining: 1.3s
# 821:	learn: 0.2553136	total: 5.96s	remaining: 1.29s
# 822:	learn: 0.2552355	total: 5.97s	remaining: 1.28s
# 823:	learn: 0.2551883	total: 5.98s	remaining: 1.28s
# 824:	learn: 0.2551350	total: 5.99s	remaining: 1.27s
# 825:	learn: 0.2551147	total: 6s	remaining: 1.26s
# 826:	learn: 0.2550734	total: 6s	remaining: 1.26s
# 827:	learn: 0.2550424	total: 6.01s	remaining: 1.25s
# 828:	learn: 0.2549745	total: 6.02s	remaining: 1.24s
# 829:	learn: 0.2549123	total: 6.03s	remaining: 1.23s
# 830:	learn: 0.2548947	total: 6.03s	remaining: 1.23s
# 831:	learn: 0.2548510	total: 6.04s	remaining: 1.22s
# 832:	learn: 0.2548031	total: 6.05s	remaining: 1.21s
# 833:	learn: 0.2547590	total: 6.06s	remaining: 1.21s
# 834:	learn: 0.2547388	total: 6.07s	remaining: 1.2s
# 835:	learn: 0.2546943	total: 6.08s	remaining: 1.19s
# 836:	learn: 0.2546654	total: 6.09s	remaining: 1.19s
# 837:	learn: 0.2546288	total: 6.1s	remaining: 1.18s
# 838:	learn: 0.2546074	total: 6.1s	remaining: 1.17s
# 839:	learn: 0.2545718	total: 6.11s	remaining: 1.16s
# 840:	learn: 0.2545153	total: 6.12s	remaining: 1.16s
# 841:	learn: 0.2544553	total: 6.13s	remaining: 1.15s
# 842:	learn: 0.2544287	total: 6.14s	remaining: 1.14s
# 843:	learn: 0.2543788	total: 6.14s	remaining: 1.14s
# 844:	learn: 0.2543318	total: 6.15s	remaining: 1.13s
# 845:	learn: 0.2543088	total: 6.16s	remaining: 1.12s
# 846:	learn: 0.2542647	total: 6.17s	remaining: 1.11s
# 847:	learn: 0.2542268	total: 6.18s	remaining: 1.11s
# 848:	learn: 0.2541951	total: 6.19s	remaining: 1.1s
# 849:	learn: 0.2541624	total: 6.19s	remaining: 1.09s
# 850:	learn: 0.2541232	total: 6.2s	remaining: 1.09s
# 851:	learn: 0.2541145	total: 6.21s	remaining: 1.08s
# 852:	learn: 0.2540689	total: 6.22s	remaining: 1.07s
# 853:	learn: 0.2540344	total: 6.22s	remaining: 1.06s
# 854:	learn: 0.2539985	total: 6.23s	remaining: 1.06s
# 855:	learn: 0.2539401	total: 6.24s	remaining: 1.05s
# 856:	learn: 0.2538845	total: 6.25s	remaining: 1.04s
# 857:	learn: 0.2538673	total: 6.26s	remaining: 1.03s
# 858:	learn: 0.2538163	total: 6.27s	remaining: 1.03s
# 859:	learn: 0.2537982	total: 6.28s	remaining: 1.02s
# 860:	learn: 0.2537720	total: 6.29s	remaining: 1.01s
# great_gpt2_12_layer_adult                 0.786043            0.004309
# great_gpt2_6_layer_adult                  0.777030            0.003556
# realtab_gpt2_12_layer_adult               0.795454            0.001883
# realtab_gpt2_6_layer_adult                0.801522            0.002989
# realtab_gpt_bigcode_12_layer_adult        0.792441            0.004352
# realtab_gpt_bigcode_6_layer_adult         0.806099            0.005174
# realtab_gpt_neo_2_layer_adult             0.793311            0.017591
# realtab_gpt_neo_4_layer_adult             0.784295            0.001649
# realtab_gpt_neo_6_layer_adult             0.767416            0.003105
# realtab_gpt_neo_8_layer_adult             0.773803            0.004173
# realtab_llama_1_layer_adult               0.778701            0.002304
# realtab_llama_2_layer_adult               0.812146            0.008456
# original                                  0.779398            0.000000

# %%
pd.DataFrame(stats).loc[["accuracy", "accuracy_std"]].T
# Out:
#                                     accuracy  accuracy_std
# great_gpt2_12_layer_adult           0.847692      0.003734
# great_gpt2_6_layer_adult            0.841908      0.001113
# realtab_gpt2_12_layer_adult         0.838218      0.001094
# realtab_gpt2_6_layer_adult          0.860990      0.001876
# realtab_gpt_bigcode_12_layer_adult  0.852402      0.002712
# realtab_gpt_bigcode_6_layer_adult   0.857568      0.003572
# realtab_gpt_neo_2_layer_adult       0.850450      0.012629
# realtab_gpt_neo_4_layer_adult       0.833897      0.001962
# realtab_gpt_neo_6_layer_adult       0.846095      0.001890
# realtab_gpt_neo_8_layer_adult       0.846122      0.001943
# realtab_llama_1_layer_adult         0.845813      0.002197
# realtab_llama_2_layer_adult         0.867633      0.005160
# original                            0.845008      0.000000

# %% [markdown]
# ## Decision Tree

# %%
import pandas as pd
import numpy as np

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score, accuracy_score, roc_auc_score, precision_score, recall_score 
from sklearn.preprocessing import LabelEncoder

import os

from general_mle import mle_adult

# %%
file_name = "adult_original_test.csv"
org_test_df = pd.read_csv(f"../data_split/original_test_dataset/{file_name}")

org_test_df.head()
# Out:
#    age workclass  fnlwgt  educational-num marital-status    occupation  \
# 0   32    Others   33117               11        Married        Others
# 1   51    Others  233149               12        Married  White Collar
# 2   84    Others  188328                9         Single  White Collar
# 3   45    Others  158685                9         Single  White Collar
# 4   44    Others  112847                4        Married   Blue Collar
#
#                  race  gender  capital-gain  capital-loss  hours-per-week  \
# 0               White    Male             0             0              40
# 1               White    Male             0             0              45
# 2               White  Female             0             0              16
# 3               White  Female             0             0              40
# 4  Asian-Pac-Islander    Male             0             0              40
#
#   native-country income
# 0  United-States  <=50K
# 1  United-States   >50K
# 2  United-States  <=50K
# 3  United-States  <=50K
# 4    Philippines  <=50K

# %%
file_name = "adult_original_train.csv"
org_train_df = pd.read_csv(f"../data_split/original_train_dataset/{file_name}")

org_train_df.head()
# Out:
#    age workclass  fnlwgt  educational-num marital-status    occupation   race  \
# 0   22    Others   51362               13         Single  White Collar  White
# 1   41    Others  203217                4         Single   Blue Collar  White
# 2   25    Others   51498                8         Single        Others  White
# 3   28    Others  179512                9         Single  White Collar  White
# 4   42    Others  177989                9        Married   Blue Collar  White
#
#    gender  capital-gain  capital-loss  hours-per-week native-country income
# 0  Female             0             0              16  United-States  <=50K
# 1    Male             0             0              40         Mexico  <=50K
# 2    Male             0             0              40  United-States  <=50K
# 3  Female             0             0              50  United-States  <=50K
# 4    Male             0             0              40  United-States  <=50K

# %%
dataset_folder = "adult"
dataset_folder = f"../generated_datasets/{dataset_folder}"


temp = mle_adult(org_test_df=org_test_df, org_train_df=org_train_df, ml_model=DecisionTreeClassifier(random_state=32), 
        path_to_synthetic_data=dataset_folder)

# %%
temp
# Out:
# {'great_gpt2_12_layer_adult': {'f1_score_micro': 0.8149490069779924,
#   'f1_score_micro_std': 0.003727608546234778,
#   'f1_score_macro': 0.7477966232972572,
#   'f1_score_macro_std': 0.0046195799768698215,
#   'f1_score_weighted': 0.8125291930424314,
#   'f1_score_weighted_std': 0.0035911783703025113,
#   'accuracy': 0.8149490069779924,
#   'accuracy_std': 0.003727608546234778,
#   'precision': 0.642426371600226,
#   'precision_std': 0.010492776098655067,
#   'recall': 0.5947787343021197,
#   'recall_std': 0.005711077601585539},
#  'great_gpt2_6_layer_adult': {'f1_score_micro': 0.8106816961889425,
#   'f1_score_micro_std': 0.0025268601683942557,
#   'f1_score_macro': 0.7416808242490783,
#   'f1_score_macro_std': 0.004801703992005672,
#   'f1_score_weighted': 0.8081157381017876,
#   'f1_score_weighted_std': 0.002525806672215223,
#   'accuracy': 0.8106816961889425,
#   'accuracy_std': 0.0025268601683942557,
#   'precision': 0.6334420242938806,
#   'precision_std': 0.011250292738751586,
#   'recall': 0.5849140478403381,
#   'recall_std': 0.008362544367121775},
#  'realtab_gpt2_12_layer_adult': {'f1_score_micro': 0.8039989264626947,
#   'f1_score_micro_std': 0.0024439005137571667,
#   'f1_score_macro': 0.7617332723261052,
#   'f1_score_macro_std': 0.0036934795693870552,
#   'f1_score_weighted': 0.8005875281809448,
#   'f1_score_weighted_std': 0.002476561322380663,
#   'accuracy': 0.8039989264626947,
#   'accuracy_std': 0.0024439005137571667,
#   'precision': 0.7026875307580617,
#   'precision_std': 0.008210856015197396,
#   'recall': 0.6247033490022145,
#   'recall_std': 0.006404517290471033},
#  'realtab_gpt2_6_layer_adult': {'f1_score_micro': 0.8196457326892108,
#   'f1_score_micro_std': 0.003378872332800383,
#   'f1_score_macro': 0.7563424034284022,
#   'f1_score_macro_std': 0.0040220222811290585,
#   'f1_score_weighted': 0.8204093136164488,
#   'f1_score_weighted_std': 0.0034515314676611974,
#   'accuracy': 0.8196457326892108,
#   'accuracy_std': 0.003378872332800383,
#   'precision': 0.6243346689120272,
#   'precision_std': 0.006846497845408957,
#   'recall': 0.6402056418243316,
#   'recall_std': 0.00732337516078276},
#  'realtab_gpt_bigcode_12_layer_adult': {'f1_score_micro': 0.8168947933440688,
#   'f1_score_micro_std': 0.0036172816208223093,
#   'f1_score_macro': 0.7548075986525061,
#   'f1_score_macro_std': 0.004431947032717777,
#   'f1_score_weighted': 0.8172550387475092,
#   'f1_score_weighted_std': 0.0035302712619997736,
#   'accuracy': 0.8168947933440688,
#   'accuracy_std': 0.0036172816208223093,
#   'precision': 0.6278126943080636,
#   'precision_std': 0.009758750379698151,
#   'recall': 0.6351399688565309,
#   'recall_std': 0.005808549913080774},
#  'realtab_gpt_bigcode_6_layer_adult': {'f1_score_micro': 0.8178878153515834,
#   'f1_score_micro_std': 0.004345319615754738,
#   'f1_score_macro': 0.7642498309919283,
#   'f1_score_macro_std': 0.004962993324068336,
#   'f1_score_weighted': 0.8167408041281232,
#   'f1_score_weighted_std': 0.004244547820745218,
#   'accuracy': 0.8178878153515834,
#   'accuracy_std': 0.004345319615754738,
#   'precision': 0.664852399385824,
#   'precision_std': 0.010350654671804663,
#   'recall': 0.6392972692046591,
#   'recall_std': 0.005462709814789198},
#  'realtab_gpt_neo_2_layer_adult': {'f1_score_micro': 0.8210810810810811,
#   'f1_score_micro_std': 0.01883938666882827,
#   'f1_score_macro': 0.7652083884506167,
#   'f1_score_macro_std': 0.023870814788152925,
#   'f1_score_weighted': 0.8237229022051465,
#   'f1_score_weighted_std': 0.018112056355236432,
#   'accuracy': 0.8210810810810811,
#   'accuracy_std': 0.01883938666882827,
#   'precision': 0.6242417710796898,
#   'precision_std': 0.04577860183335508,
#   'recall': 0.6806234232770306,
#   'recall_std': 0.030586486773744093},
#  'realtab_gpt_neo_4_layer_adult': {'f1_score_micro': 0.7981615673644659,
#   'f1_score_micro_std': 0.0023128205214302325,
#   'f1_score_macro': 0.7501304110929092,
#   'f1_score_macro_std': 0.003300665773848634,
#   'f1_score_weighted': 0.7962033206988385,
#   'f1_score_weighted_std': 0.002293851931389908,
#   'accuracy': 0.7981615673644659,
#   'accuracy_std': 0.0023128205214302325,
#   'precision': 0.6616871206406689,
#   'precision_std': 0.007883084181482782,
#   'recall': 0.6208272894063577,
#   'recall_std': 0.005948184865586642},
#  'realtab_gpt_neo_6_layer_adult': {'f1_score_micro': 0.8066156736446592,
#   'f1_score_micro_std': 0.0019349979482360144,
#   'f1_score_macro': 0.7254507928497584,
#   'f1_score_macro_std': 0.003147178103830981,
#   'f1_score_weighted': 0.8139216227110071,
#   'f1_score_weighted_std': 0.0018161301986784851,
#   'accuracy': 0.8066156736446592,
#   'accuracy_std': 0.0019349979482360144,
#   'precision': 0.5203568133366248,
#   'precision_std': 0.005127437334238366,
#   'recall': 0.6454356696706564,
#   'recall_std': 0.007885738883605692},
#  'realtab_gpt_neo_8_layer_adult': {'f1_score_micro': 0.8092860976918947,
#   'f1_score_micro_std': 0.0026332968269254624,
#   'f1_score_macro': 0.7356773716188604,
#   'f1_score_macro_std': 0.004797849467386052,
#   'f1_score_weighted': 0.8101764454768775,
#   'f1_score_weighted_std': 0.002815866161170109,
#   'accuracy': 0.8092860976918947,
#   'accuracy_std': 0.0026332968269254624,
#   'precision': 0.5881992603696387,
#   'precision_std': 0.006250550039751593,
#   'recall': 0.604463949738214,
#   'recall_std': 0.01207372249771942},
#  'realtab_llama_1_layer_adult': {'f1_score_micro': 0.8095544820182502,
#   'f1_score_micro_std': 0.002508980794531114,
#   'f1_score_macro': 0.7413297507164346,
#   'f1_score_macro_std': 0.003431101515430879,
#   'f1_score_weighted': 0.8149655833961704,
#   'f1_score_weighted_std': 0.0026986908128405914,
#   'accuracy': 0.8095544820182502,
#   'accuracy_std': 0.002508980794531114,
#   'precision': 0.5614598638535142,
#   'precision_std': 0.00511361643888449,
#   'recall': 0.6641458245898268,
#   'recall_std': 0.007969286907770446},
#  'realtab_llama_2_layer_adult': {'f1_score_micro': 0.8364868491680086,
#   'f1_score_micro_std': 0.0031388490715823715,
#   'f1_score_macro': 0.7776474574741157,
#   'f1_score_macro_std': 0.005706811212305639,
#   'f1_score_weighted': 0.8360623370158772,
#   'f1_score_weighted_std': 0.0034851840169801166,
#   'accuracy': 0.8364868491680086,
#   'accuracy_std': 0.0031388490715823715,
#   'precision': 0.6682736663696154,
#   'precision_std': 0.0060977594416354785,
#   'recall': 0.6584659588663178,
#   'recall_std': 0.015801271552952013},
#  'original': {'f1_score_micro': 0.8072329575952765,
#   'f1_score_micro_std': 0,
#   'f1_score_macro': 0.7425390952471502,
#   'f1_score_macro_std': 0,
#   'f1_score_weighted': 0.808679065882271,
#   'f1_score_weighted_std': 0,
#   'accuracy': 0.8072329575952765,
#   'accuracy_std': 0,
#   'precision': 0.6,
#   'precision_std': 0,
#   'recall': 0.6275805119735756,
#   'recall_std': 0}}

# %%
pd.DataFrame(temp).loc[["f1_score_macro", "f1_score_macro_std"]].T
# Out:
#                                     f1_score_macro  f1_score_macro_std
# great_gpt2_12_layer_adult                 0.747797            0.004620
# great_gpt2_6_layer_adult                  0.741681            0.004802
# realtab_gpt2_12_layer_adult               0.761733            0.003693
# realtab_gpt2_6_layer_adult                0.756342            0.004022
# realtab_gpt_bigcode_12_layer_adult        0.754808            0.004432
# realtab_gpt_bigcode_6_layer_adult         0.764250            0.004963
# realtab_gpt_neo_2_layer_adult             0.765208            0.023871
# realtab_gpt_neo_4_layer_adult             0.750130            0.003301
# realtab_gpt_neo_6_layer_adult             0.725451            0.003147
# realtab_gpt_neo_8_layer_adult             0.735677            0.004798
# realtab_llama_1_layer_adult               0.741330            0.003431
# realtab_llama_2_layer_adult               0.777647            0.005707
# original                                  0.742539            0.000000

# %%
pd.DataFrame(temp).loc[["accuracy", "accuracy_std"]].T
# Out:
#                                     accuracy  accuracy_std
# great_gpt2_12_layer_adult           0.814949      0.003728
# great_gpt2_6_layer_adult            0.810682      0.002527
# realtab_gpt2_12_layer_adult         0.803999      0.002444
# realtab_gpt2_6_layer_adult          0.819646      0.003379
# realtab_gpt_bigcode_12_layer_adult  0.816895      0.003617
# realtab_gpt_bigcode_6_layer_adult   0.817888      0.004345
# realtab_gpt_neo_2_layer_adult       0.821081      0.018839
# realtab_gpt_neo_4_layer_adult       0.798162      0.002313
# realtab_gpt_neo_6_layer_adult       0.806616      0.001935
# realtab_gpt_neo_8_layer_adult       0.809286      0.002633
# realtab_llama_1_layer_adult         0.809554      0.002509
# realtab_llama_2_layer_adult         0.836487      0.003139
# original                            0.807233      0.000000
