# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score 
from sklearn.preprocessing import LabelEncoder

import os
from general_dm import dm_housing

# %%
file_name = "housing_original_test.csv"
org_test_df = pd.read_csv(f"../data_split/original_test_dataset/{file_name}")

org_test_df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -121.36     38.57                26.0       1793.0           244.0
# 1    -119.76     36.75                35.0       1607.0           383.0
# 2    -122.47     37.95                16.0       3769.0           839.0
# 3    -118.48     34.47                36.0         84.0            12.0
# 4    -118.35     34.03                43.0       2122.0           524.0
#
#    population  households  median_income ocean_proximity  median_house_value
# 0       653.0       235.0         5.6485          INLAND            129500.0
# 1      1407.0       382.0         2.1900          INLAND             53400.0
# 2      1986.0       815.0         3.9712        NEAR BAY            187500.0
# 3        29.0        17.0         3.3750       <1H OCEAN            187500.0
# 4      1510.0       436.0         2.2273       <1H OCEAN            123300.0

# %%
file_name = "housing_original_train.csv"
org_train_df = pd.read_csv(f"../data_split/original_train_dataset/{file_name}")

org_train_df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -118.62     34.22                34.0       2633.0           471.0
# 1    -117.15     32.91                14.0       1259.0           238.0
# 2    -122.32     40.57                15.0       2524.0           449.0
# 3    -118.41     34.18                35.0       2785.0           663.0
# 4    -118.26     33.91                39.0        967.0           256.0
#
#    population  households  median_income ocean_proximity  median_house_value
# 0      1313.0       428.0         4.0909       <1H OCEAN            232900.0
# 1       889.0       247.0         4.9464       <1H OCEAN            174800.0
# 2      1374.0       467.0         3.3816          INLAND             93800.0
# 3      1631.0       614.0         3.9038       <1H OCEAN            276100.0
# 4       903.0       256.0         1.9038       <1H OCEAN             93100.0

# %%
temp = dm_housing(org_train_df=org_train_df, org_test_df=org_test_df, ml_model=RandomForestClassifier(random_state=32), 
                path_to_synthetic_dataset="../generated_datasets/housing")
# Out:
# great_gpt2_12_layer_housing
# 1
# 2
# 3
# 4
# 5
# great_gpt2_6_layer_housing
# 1
# 2
# 3
# 4
# 5
# great_gpt_j_1_layer_housing
# 1
# 2
# 3
# 4
# 5
# great_gpt_neox_1_layer_housing
# 1
# 2
# 3
# 4
# 5
# great_gpt_neo_2_layer_housing
# 1
# 2
# 3
# 4
# 5
# great_gpt_neo_4_layer_housing
# 1
# 2
# 3
# 4
# 5
# great_gpt_neo_6_layer_housing
# 1
# 2
# 3
# 4
# 5
# great_gpt_neo_8_layer_housing
# 1
# 2
# 3
# 4
# 5
# realtab_gpt2_12_layer_housing
# 1
# 2
# 3
# 4
# 5
# realtab_gpt2_6_layer_housing
# 1
# 2
# 3
# 4
# 5
# realtab_gpt_bigcode_12_layer_housing
# 1
# 2
# 3
# 4
# 5
# realtab_gpt_bigcode_6_layer_housing
# 1
# 2
# 3
# 4
# 5
# realtab_gpt_neox_1_layer_housing
# 1
# 2
# 3
# 4
# 5
# realtab_gpt_neo_2_layer_housing
# 1
# 2
# 3
# 4
# 5
# realtab_gpt_neo_4_layer_housing
# 1
# 2
# 3
# 4
# 5
# realtab_gpt_neo_6_layer_housing
# 1
# 2
# 3
# 4
# 5
# realtab_gpt_neo_8_layer_housing
# 1
# 2
# 3
# 4
# 5
# realtab_llama_1_layer_housing
# 1
# 2
# 3
# 4
# 5
# realtab_llama_2_layer_housing
# 1
# 2
# 3
# 4
# 5

# %%
pd.DataFrame(temp).T
# Out:
#                                       accuracy  accuracy_std
# great_gpt2_12_layer_housing           0.759958      0.004104
# great_gpt2_6_layer_housing            0.774685      0.004939
# great_gpt_j_1_layer_housing           0.924114      0.003160
# great_gpt_neox_1_layer_housing        0.901528      0.001174
# great_gpt_neo_2_layer_housing         0.754234      0.003240
# great_gpt_neo_4_layer_housing         0.718642      0.002663
# great_gpt_neo_6_layer_housing         0.730446      0.003806
# great_gpt_neo_8_layer_housing         0.712813      0.003107
# realtab_gpt2_12_layer_housing         0.598295      0.003479
# realtab_gpt2_6_layer_housing          0.602669      0.001274
# realtab_gpt_bigcode_12_layer_housing  0.601528      0.002753
# realtab_gpt_bigcode_6_layer_housing   0.599600      0.004623
# realtab_gpt_neox_1_layer_housing      0.645959      0.003143
# realtab_gpt_neo_2_layer_housing       0.621771      0.002663
# realtab_gpt_neo_4_layer_housing       0.611760      0.003098
# realtab_gpt_neo_6_layer_housing       0.614370      0.004878
# realtab_gpt_neo_8_layer_housing       0.618701      0.003083
# realtab_llama_1_layer_housing         0.681017      0.003003
# realtab_llama_2_layer_housing         0.646567      0.003598
